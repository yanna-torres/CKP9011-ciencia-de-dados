# %% [markdown]
# # Lista 09 - Agrupamento
#
# > Yanna Torres Gonçalves
# >
# > Matrícula: 587299
# >
# > Mestrado em Ciências da Computação

# %% [markdown]
# ## Setup: limpeza e pré-processamento dos dados

# %%
# !pip install nltk

# %%
# !pip install pyLDAvis

# %%
import pandas as pd
import numpy as np
import re
from tqdm import tqdm
tqdm.pandas()

import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

pyLDAvis.enable_notebook()

# %%
data_url = "https://media.githubusercontent.com/media/yanna-torres/CKP9011-ciencia-de-dados/refs/heads/lista-01/data/fakeTelegram.BR_2022.csv"

df = pd.read_csv(data_url)

# %%
df.describe()
# Out:
#        dataset_info_id  score_sentiment  score_misinformation    id_message
# count         557586.0    444157.000000         167238.000000  5.575860e+05
# mean               5.0         0.017330              0.312245  4.450617e+05
# std                0.0         0.464165              0.293699  4.860211e+05
# min                5.0        -1.000000              0.000003  2.000000e+00
# 25%                5.0        -0.177900              0.078454  2.127500e+04
# 50%                5.0         0.000000              0.197577  1.210935e+05
# 75%                5.0         0.318200              0.490351  9.726045e+05
# max                5.0         0.999200              1.000000  1.516436e+06

# %%
def has_trava_zap(message):
    if not isinstance(message, str):
        return False  # Garante que só analisa strings

    # Regra 1: muito longo
    if len(message) > 10000:
        return True

    # Regra 2: caracteres invisíveis
    invisible = ''.join(chr(c) for c in range(0x200B, 0x200F + 1)) + '\uFEFF'
    if sum(message.count(c) for c in invisible) > 100:
        return True

    # Regra 3: emojis repetidos
    emoji_pattern = re.compile("[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF"
                              "\U0001F680-\U0001F6FF\U0001F1E0-\U0001F1FF]+", flags=re.UNICODE)
    emojis = emoji_pattern.findall(message)
    if any(len(e) > 20 for e in emojis):
        return True

    # Regra 4: baixa diversidade
    unique = set(message)
    if len(unique) < 10 and len(message) > 500:
        return True

    return False

# %%
df['trava_zap'] = df['text_content_anonymous'].apply(has_trava_zap)
df_clean = df[df['trava_zap'] == False]
df_clean.drop(columns=['trava_zap'], inplace=True)
# Out:
# /tmp/ipykernel_4369/1981750910.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.drop(columns=['trava_zap'], inplace=True)

# %%
df_clean = df_clean.drop_duplicates()

# %%
df_clean = df_clean[df_clean['text_content_anonymous'].str.split().str.len() >= 5]

# %%
df_clean.columns
# Out:
# Index(['date_message', 'id_member_anonymous', 'id_group_anonymous', 'media',
#        'media_type', 'media_url', 'has_media', 'has_media_url',
#        'text_content_anonymous', 'dataset_info_id', 'date_system',
#        'score_sentiment', 'score_misinformation', 'id_message', 'message_type',
#        'messenger', 'media_name', 'media_md5'],
#       dtype='object')

# %% [markdown]
# ## Pré-processar o texto

# %%
texts = df_clean['text_content_anonymous'].dropna().astype(str).tolist()

# %%
stop_words = set(stopwords.words('portuguese', 'english'))

def preprocess(text):
    text = text.lower()
    text = re.sub(r'https?://\S+|www\.\S+', '', text)  # remove URLs
    text = re.sub(r'[^a-záéíóúâêîôûãõç\s]', '', text)  # remove punctuation
    tokens = word_tokenize(text, language='portuguese')
    return [word for word in tokens if word not in stop_words and len(word) > 2]

texts_preprocessed = [preprocess(text) for text in texts]

# %% [markdown]
# ## Avaliação Experimental

# %% [markdown]
# ### Latent Dirichlet Allocation (LDA)

# %%
# !pip install gensim

# %%
from gensim import corpora, models

dictionary = corpora.Dictionary(texts_preprocessed)
corpus = [dictionary.doc2bow(text) for text in texts_preprocessed]

lda_model = models.LdaModel(corpus=corpus, num_topics=5, id2word=dictionary, passes=10)

for idx, topic in lda_model.print_topics(-1):
    print(f"Topic {idx}: {topic}")
# Out:
# Topic 0: 0.007*"brasil" + 0.007*"deus" + 0.006*"sobre" + 0.005*"contra" + 0.005*"dia" + 0.005*"todos" + 0.004*"dias" + 0.004*"governo" + 0.004*"sistema" + 0.004*"mundo"
# Topic 1: 0.012*"bolsonaro" + 0.012*"agora" + 0.012*"todos" + 0.011*"povo" + 0.010*"vai" + 0.010*"pra" + 0.010*"brasil" + 0.009*"vamos" + 0.007*"fazer" + 0.006*"tudo"
# Topic 2: 0.088*"user" + 0.055*"canal" + 0.050*"grupo" + 0.029*"link" + 0.022*"telegram" + 0.018*"youtube" + 0.017*"verdade" + 0.013*"inscreva" + 0.013*"envie" + 0.012*"compartilhe"
# Topic 3: 0.040*"the" + 0.033*"brazil" + 0.030*"this" + 0.029*"tse" + 0.027*"superior" + 0.027*"was" + 0.027*"court" + 0.027*"decision" + 0.027*"electoral" + 0.027*"following"
# Topic 4: 0.027*"lula" + 0.017*"bolsonaro" + 0.012*"tse" + 0.009*"brasil" + 0.008*"presidente" + 0.007*"militar" + 0.007*"diz" + 0.007*"veja" + 0.006*"eleições" + 0.006*"sobre"

# %%
lda_vis = gensimvis.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(lda_vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el43691401062097566563163736795" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el43691401062097566563163736795_data = {"mdsDat": {"x": [0.20380133224506375, 0.1698684545827359, 0.16521567944611817, -0.28807532976922756, -0.25081013650469], "y": [-0.014325606133831768, -0.024489736766686688, 0.01381989151876357, -0.2969382469144058, 0.32193369829616064], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [32.085582126558734, 27.08091590663945, 18.880246121603133, 12.447687477001136, 9.505568368197537]}, "tinfo": {"Term": ["user", "canal", "grupo", "the", "brazil", "tse", "this", "lula", "was", "court", "decision", "electoral", "following", "blocked", "community", "superior", "link", "bolsonaro", "ganhar", "come\u00e7ar", "aqui", "telegram", "verdade", "dinheiro", "youtube", "plataforma", "pra", "povo", "vai", "comigo", "pra", "ruas", "gente", "pessoal", "patriotas", "v\u00e3o", "quart\u00e9is", "coisa", "fazendo", "ffaa", "fake", "pau", "votar", "pedir", "ningu\u00e9m", "precisamos", "pro", "algo", "querem", "caminhoneiros", "quarteis", "sabe", "podemos", "nao", "sos", "fiquem", "parar", "petistas", "acontecendo", "nessa", "nada", "saber", "bora", "vamos", "m\u00e3o", "vai", "povo", "ver", "esquerda", "agora", "manifesta\u00e7\u00e3o", "fazer", "tudo", "dar", "hora", "todos", "grupos", "for\u00e7as", "armadas", "aten\u00e7\u00e3o", "bolsonaro", "fraude", "pessoas", "brasil", "quer", "presidente", "pode", "aqui", "ter", "interven\u00e7\u00e3o", "dia", "sobre", "lula", "todo", "covid", "trem", "digital", "senhor", "livro", "permite", "vacina", "reais", "ora\u00e7\u00e3o", "vacinas", "mundial", "passageiros", "redu\u00e7\u00e3o", "vale", "sociedade", "\u00fatero", "internacionais", "m\u00eas", "estudo", "vacina\u00e7\u00e3o", "transporte", "entrevista", "homem", "pol\u00edticas", "pfizer", "implanta\u00e7\u00e3o", "constru\u00e7\u00e3o", "pena", "d\u00favida", "minutos", "valor", "fome", "projeto", "mercado", "servi\u00e7os", "sa\u00fade", "vida", "t\u00e9cnica", "membros", "lei", "dentro", "livre", "plano", "meio", "acesso", "acordo", "deus", "drogas", "contra", "jesus", "dias", "mundo", "sistema", "governo", "sempre", "dia", "sobre", "grande", "brasil", "fim", "todos", "poder", "pessoas", "hoje", "anos", "ainda", "tempo", "todo", "porque", "dinheiro", "todas", "pa\u00eds", "liberdade", "veja", "moraes", "federal", "tribunal", "ministro", "globo", "jovem", "inser\u00e7\u00f5es", "pan", "r\u00e1dios", "partido", "pesquisa", "eletr\u00f4nico", "general", "norte", "rep\u00fablica", "jefferson", "mandato", "zona", "autoridades", "trabalhadores", "deputado", "empres\u00e1rios", "r\u00e1dio", "governador", "processos", "congresso", "senado", "auditoria", "prf", "tramita\u00e7\u00e3o", "paulista", "eleitoral", "alexandre", "militar", "lula", "minist\u00e9rio", "diz", "fonte", "decis\u00e3o", "defesa", "paulo", "elei\u00e7\u00f5es", "bolsonaro", "ap\u00f3s", "campanha", "tse", "presidente", "stf", "segundo", "urnas", "relat\u00f3rio", "interven\u00e7\u00e3o", "brasil", "urgente", "sobre", "governo", "votos", "rua", "v\u00eddeo", "the", "brazil", "this", "was", "court", "decision", "following", "blocked", "community", "electoral", "come\u00e7ar", "plataforma", "bot", "comigo", "investir", "ativar", "feedback", "conectese", "tmearthursennatrader", "obrigado", "investimento", "parab\u00e9ns", "and", "empresa", "feliz", "you", "bitcoin", "conosco", "retirada", "invista", "truth", "shall", "ganhar", "superior", "posso", "dinheiro", "tse", "aqui", "user", "anos", "pode", "canal", "grupo", "telegram", "youtube", "inscreva", "assista", "ol\u00e1", "welcome", "groups", "professional", "tool", "managing", "vindoa", "administradores", "convite", "chame", "relate", "digitando", "red", "pill", "especulando", "visitem", "gettr", "maria", "tmeewlgmatrzggotlh", "zambelli", "leiam", "lembrese", "tmeewzipdzveynzjh", "topo", "link", "phone", "conhecereis", "libertar\u00e1", "divulgue", "fatos", "envie", "user", "acesse", "oficial", "abaixo", "verdade", "compartilhe", "jo\u00e3o", "whatsapp", "liberdade", "bem", ...

# %% [markdown]
# ### Gibbs Sampling Dirichlet Multinomial Mixture (GSDMM)

# %%
# !pip install git+https://github.com/rwalk/gsdmm.git

# %%
from gsdmm import MovieGroupProcess

mgp = MovieGroupProcess(K=5, alpha=0.1, beta=0.3, n_iters=30)
vocab = set(word for doc in texts_preprocessed for word in doc)
vocab_size = len(vocab)

mgp.fit(texts_preprocessed, vocab_size)
# Out:
# In stage 0: transferred 264788 clusters with 5 clusters populated
# In stage 1: transferred 132169 clusters with 5 clusters populated
# In stage 2: transferred 46830 clusters with 5 clusters populated
# In stage 3: transferred 28008 clusters with 5 clusters populated
# In stage 4: transferred 23187 clusters with 5 clusters populated
# In stage 5: transferred 21683 clusters with 5 clusters populated
# In stage 6: transferred 21137 clusters with 5 clusters populated
# In stage 7: transferred 20659 clusters with 5 clusters populated
# In stage 8: transferred 20357 clusters with 5 clusters populated
# In stage 9: transferred 19973 clusters with 5 clusters populated
# In stage 10: transferred 19916 clusters with 5 clusters populated
# In stage 11: transferred 19454 clusters with 5 clusters populated
# In stage 12: transferred 19464 clusters with 5 clusters populated
# In stage 13: transferred 19459 clusters with 5 clusters populated
# In stage 14: transferred 19574 clusters with 5 clusters populated
# In stage 15: transferred 19396 clusters with 5 clusters populated
# In stage 17: transferred 19327 clusters with 5 clusters populated
# In stage 18: transferred 19337 clusters with 5 clusters populated
# In stage 19: transferred 19242 clusters with 5 clusters populated
# In stage 20: transferred 19105 clusters with 5 clusters populated
# In stage 21: transferred 19268 clusters with 5 clusters populated
# In stage 22: transferred 18986 clusters with 5 clusters populated
# In stage 23: transferred 19153 clusters with 5 clusters populated
# In stage 24: transferred 19058 clusters with 5 clusters populated
# In stage 25: transferred 19086 clusters with 5 clusters populated
# In stage 26: transferred 19171 clusters with 5 clusters populated
# In stage 27: transferred 19062 clusters with 5 clusters populated
# In stage 28: transferred 19094 clusters with 5 clusters populated
# In stage 29: transferred 19159 clusters with 5 clusters populated
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 11
#       9 # Display topics
#      10 for topic in range(mgp.K):
# ---> 11     top_words = mgp.get_top_words(topic, 10)
#      12     print(f'Topic {topic}: {top_words}\n')
#
# AttributeError: 'MovieGroupProcess' object has no attribute 'get_top_words'

# %% [markdown]
# ### Pseudo-document based Topic Model (PTM)

# %% [markdown]
# ### BERTopic

# %%
# !pip install bertopic

# %%
from bertopic import BERTopic

# Flatten texts back into sentences
documents = [' '.join(text) for text in texts_preprocessed]

topic_model = BERTopic(language="portuguese")
topics, probs = topic_model.fit_transform(documents)
topic_model.get_topic_info()
